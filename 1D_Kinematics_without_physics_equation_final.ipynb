# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholassung97/DemonstrationofPINNs/blob/main/1D_Kinematics_without_physics_equation_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***1D Kinematics Equation without PINNs***
#
#
#
#
# ---

# %% [markdown]
# #Setting Up Libraries

# %% [markdown]
# Install the pyDOE library

# %%
# !pip install --upgrade pyDOE
# Out:
# Requirement already satisfied: pyDOE in /usr/local/lib/python3.7/dist-packages (0.3.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.21.6)

# %% [markdown]
# Import the other flow libraries
# (Convert tensorflow to version 1)

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
from pyDOE import lhs
from mpl_toolkits.mplot3d import Axes3D
import time
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Random Seed

# %%
np.random.seed(1234)
tf.set_random_seed(1234) # New version of tensorflow uses random.set_seed instead

# %% [markdown]
# Install Latex Package

# %%
# !sudo apt-get install texlive-latex-extra texlive-fonts-recommended dvipng cm-super
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cm-super is already the newest version (0.3.4-11).
# dvipng is already the newest version (1.15-1).
# texlive-fonts-recommended is already the newest version (2017.20180305-1).
# texlive-latex-extra is already the newest version (2017.20180305-2).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %% [markdown]
# #Setting Up PhysicsInformedNN

# %%
class PhysicsInformedNN:
    # Initialize the class
      def __init__(self, t_b, x_b, layers, lb, ub):
        
        self.lb = lb
        self.ub = ub
        # Boundary conditions of x(t=0)=0 and x(t=10)=0
        # Time boundary conditions
        self.t_b = t_b
        # Displacement boundary conditions
        self.x_b = x_b
        # Function time conditions
        # self.t_f = t_f
        # Neurons in each layer
        self.layers = layers
        
        # Initialize NNs
        self.weights, self.biases = self.initialize_NN(layers)
        
        # tf placeholders and graph
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))

        self.t_b_tf = tf.placeholder(tf.float32, shape=[None, self.t_b.shape[1]])        
        self.x_b_tf = tf.placeholder(tf.float32, shape=[None, self.x_b.shape[1]])
        # self.t_f_tf = tf.placeholder(tf.float32, shape=[None, self.t_f.shape[1]])
        
        self.x_b_pred = self.net_x_b(self.t_b_tf) 
        #self.f_pred = self.net_f(self.t_f_tf)         
        
        self.loss = tf.reduce_mean(tf.square(self.x_b_tf - self.x_b_pred)) #+ \
                    # tf.reduce_mean(tf.square(self.f_pred))
               
                
        self.optimizer = tf.contrib.opt.ScipyOptimizerInterface(self.loss, 
                                                                method = 'L-BFGS-B', 
                                                                options = {'maxiter': 50000,
                                                                           'maxfun': 50000,
                                                                           'maxcor': 50,
                                                                           'maxls': 50,
                                                                           'ftol' : 1.0 * np.finfo(float).eps})
        
        init = tf.global_variables_initializer()
        self.sess.run(init)

# %% [markdown]
# Function to create weights and biases based on layers

# %%
    def initialize_NN(self, layers):          # Creates weights and biases   
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            # creates rows of zeros (len of layers)
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
    PhysicsInformedNN.initialize_NN = initialize_NN

# %% [markdown]
# Function to generate range of values based on the normal distribution

# %%
    def xavier_init(self, size):            # Generates values with following a normal distribution 
        in_dim = size[0]
        out_dim = size[1] 
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        # Initializer that generates a truncated normal distribution.
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    PhysicsInformedNN.xavier_init = xavier_init

# %% [markdown]
# Function that run through the neural network

# %%
    def neural_net(self, X, weights, biases):
        num_layers = len(weights) + 1
        
        H = 2.0*(X - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y 
    PhysicsInformedNN.neural_net = neural_net

# %% [markdown]
# Function that returns x when t is entered

# %%
    def net_x_b(self, t):
        x = self.neural_net(tf.concat([t],1), self.weights, self.biases)
        return x
    PhysicsInformedNN.net_x_b = net_x_b

# %% [markdown]
# Function that prints the loss

# %%
    def callback(self, loss):
        print('Loss:', loss)
    PhysicsInformedNN.callback = callback

# %% [markdown]
# Function that outputs iterations, loss and time given no of iterations

# %%
    def train(self):
        
        tf_dict = {self.t_b_tf: self.t_b, self.x_b_tf: self.x_b}#, self.t_f_tf: self.t_f}
                                                                                                                         
        self.optimizer.minimize(self.sess, 
                                feed_dict = tf_dict,         
                                fetches = [self.loss], 
                                loss_callback = self.callback)  
    PhysicsInformedNN.train = train

# %% [markdown]
# Functions that produces the predicted values for x and f

# %%
    def predict(self, t_star):
                
        x_star = self.sess.run(self.x_b_pred, {self.t_b_tf: t_star[:,0:1]})  
        # f_star = self.sess.run(self.f_pred, {self.t_f_tf: t_star[:,0:1]})
               
        return x_star#, f_star
    PhysicsInformedNN.predict = predict

# %% [markdown]
# # Input Training values into PhysicsInformedNN

# %% [markdown]
# Creating Training Values

# %%
# Boundary Condtions (lb: t=0 and ub: t=10 )
lb = 0
ub = 10
# Creates an array of t with intervals of 0.01
t = np.arange(lb, ub, 0.01)
x = -5*t*t + 50*t
t_star = t.flatten()[:,None]
x_star = x.flatten()[:,None]
# Layers for Neural Network
layers =  [1, 20, 1]    
# Input 75 percent of the data set as training data
idx_train = np.random.choice(t_star.shape[0], 150 , replace=False)
# idx_train = np.random.choice(t_star.shape[0], int(t_star.shape[0]*0.75) , replace=False)
t_b_train = t_star[idx_train, :]
x_b_train = x_star[idx_train, :]
idx_allvalues = np.array(list(range(0, t_star.shape[0])))

# %% [markdown]
# #Training the model

# %%
model = PhysicsInformedNN(t_b_train, x_b_train, layers, lb, ub)
start_time = time.time()                
model.train()
elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Loss: 3.176285e-05
# Loss: 3.1719348e-05
# Loss: 3.166485e-05
# Loss: 3.1638283e-05
# Loss: 3.148506e-05
# Loss: 3.1334934e-05
# Loss: 3.140861e-05
# Loss: 3.129388e-05
# Loss: 3.1477193e-05
# Loss: 3.1114487e-05
# Loss: 3.102024e-05
# Loss: 3.0777093e-05
# Loss: 3.0644915e-05
# Loss: 3.4279317e-05
# Loss: 3.0508736e-05
# Loss: 3.0404814e-05
# Loss: 3.0353134e-05
# Loss: 3.0198877e-05
# Loss: 3.0157622e-05
# Loss: 3.0085765e-05
# Loss: 2.964829e-05
# Loss: 2.9545721e-05
# Loss: 2.9469247e-05
# Loss: 2.934073e-05
# Loss: 2.9329096e-05
# Loss: 2.925586e-05
# Loss: 2.9133545e-05
# Loss: 2.8964374e-05
# Loss: 2.8982122e-05
# Loss: 2.884447e-05
# Loss: 2.8780583e-05
# Loss: 2.8740013e-05
# Loss: 2.873667e-05
# Loss: 2.8735203e-05
# Loss: 2.8682934e-05
# Loss: 2.86627e-05
# Loss: 2.8694883e-05
# Loss: 2.8670527e-05
# Loss: 2.868683e-05
# Loss: 2.8688592e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# Loss: 2.86627e-05
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 0.000029
#   Number of iterations: 788
#   Number of functions evaluations: 984
# Training time: 2.9499

# %% [markdown]
# #Interpolation

# %% [markdown]
# Predicting Interpolation Values

# %%
# idx_test = idx_allvalues[~np.isin(idx_allvalues, idx_train)]
idx_test = np.random.choice(t_star.shape[0], int(t_star.shape[0]*0.25) , replace=False)
t_b_test = t_star[idx_test, :]
x_b_test = x_star[idx_test, :]
x_pred = model.predict(t_b_test)

# %% [markdown]
# Plotting for Interpolation

# %%
from matplotlib import pyplot as plt
plt.title('Displacement (x) against Time (t) from  t=0 to t=10')
plt.plot(t_b_test, x_pred, 'x', label='Predicted Value (Normal Neural Network, 150 Training Data)')

plt.plot(t_star, x_star, 'r-', label='True Value')
plt.legend()
plt.xlabel('time (s)')
plt.ylabel('displacement (m)')
plt.show()

# %% [markdown]
# # Extrapolation

# %% [markdown]
# Predicting Exrapolation Values

# %%
lb_extrap = 10
ub_extrap = 15
t1 = np.arange(lb_extrap, ub_extrap, 0.1)
x1 = -5*t1*t1 + 50*t1
t_true_extrap = t1.flatten()[:,None]
x_true_extrap = x1.flatten()[:,None]
x_pred_extrap = model.predict(t_true_extrap)

# %% [markdown]
# Plotting for Extrapolation

# %%
from matplotlib import pyplot as plt
plt.title('Predicted and Actual Value for Extrapolation Range of t=10 to t=15 (Normal Neural Network)')
plt.plot(t_true_extrap, x_pred_extrap, 'x', label='Predicted Value')

plt.plot(t_true_extrap, x_true_extrap, 'r-', label='Actual Value')
plt.legend()
plt.xlabel('time (s)')
plt.ylabel('displacement (m)')
plt.show()
